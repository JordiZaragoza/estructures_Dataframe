# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# ### *Descarga el data set Airlines Delay: Airline on-time statistics and delay causes i cargalo en un pandas Dataframe. Explora los datos que contiene, y quedate unicamente con las columnas que consideres relevantes*

# %%
import pandas as pd

df = pd.read_csv("DelayedFlights.csv") # cargo el archivo csv
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %% [markdown]
# #### Columnas a usar

# %%
df = df[["Year","Month","DayofMonth","DepTime","CRSDepTime","ArrTime","CRSArrTime","UniqueCarrier","AirTime","ArrDelay","DepDelay","Distance","Origin","Dest"]]
df.head()
# Out:
#    Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  2008      1           3   2003.0        1955   2211.0        2225
# 1  2008      1           3    754.0         735   1002.0        1000
# 2  2008      1           3    628.0         620    804.0         750
# 3  2008      1           3   1829.0        1755   1959.0        1925
# 4  2008      1           3   1940.0        1915   2121.0        2110
#
#   UniqueCarrier  AirTime  ArrDelay  DepDelay  Distance Origin Dest
# 0            WN    116.0     -14.0       8.0       810    IAD  TPA
# 1            WN    113.0       2.0      19.0       810    IAD  TPA
# 2            WN     76.0      14.0       8.0       515    IND  BWI
# 3            WN     77.0      34.0      34.0       515    IND  BWI
# 4            WN     87.0      11.0      25.0       688    IND  JAX

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# ### *Haz un informe completo del data set:*

# %% [markdown]
# #### *Resume estadisticamente las columnas de interes*

# %%
df.describe()
# Out:
#             Year         Month    DayofMonth       DepTime    CRSDepTime  \
# count  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06  1.936758e+06
# mean      2008.0  6.111106e+00  1.575347e+01  1.518534e+03  1.467473e+03
# std          0.0  3.482546e+00  8.776272e+00  4.504853e+02  4.247668e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  1.203000e+03  1.135000e+03
# 50%       2008.0  6.000000e+00  1.600000e+01  1.545000e+03  1.510000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  1.900000e+03  1.815000e+03
# max       2008.0  1.200000e+01  3.100000e+01  2.400000e+03  2.359000e+03
#
#             ArrTime    CRSArrTime       AirTime      ArrDelay      DepDelay  \
# count  1.929648e+06  1.936758e+06  1.928371e+06  1.928371e+06  1.936758e+06
# mean   1.610141e+03  1.634225e+03  1.082771e+02  4.219988e+01  4.318518e+01
# std    5.481781e+02  4.646347e+02  6.864261e+01  5.678472e+01  5.340250e+01
# ...

# %% [markdown]
# #### *Encuentra cuantos datos faltantes hay por columna*

# %%
pd.DataFrame(df.isnull().sum())
# Out:
#                   0
# Year              0
# Month             0
# DayofMonth        0
# DepTime           0
# CRSDepTime        0
# ArrTime        7110
# CRSArrTime        0
# UniqueCarrier     0
# AirTime        8387
# ArrDelay       8387
# DepDelay          0
# Distance          0
# Origin            0
# Dest              0

# %% [markdown]
# ### *Crea columnas nuevas (velocidad media de vuelo, si ha llegado tarde o no...)*

# %%
df['AvgSpeed'] = round(df['Distance']/(df['AirTime']/60)) # velocidad media
df['ArrLate'] = df['ArrDelay']>0 # si ha llegado tarde o no
df.head()
# Out:
#    Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  2008      1           3   2003.0        1955   2211.0        2225
# 1  2008      1           3    754.0         735   1002.0        1000
# 2  2008      1           3    628.0         620    804.0         750
# 3  2008      1           3   1829.0        1755   1959.0        1925
# 4  2008      1           3   1940.0        1915   2121.0        2110
#
#   UniqueCarrier  AirTime  ArrDelay  DepDelay  Distance Origin Dest  AvgSpeed  \
# 0            WN    116.0     -14.0       8.0       810    IAD  TPA     419.0
# 1            WN    113.0       2.0      19.0       810    IAD  TPA     430.0
# 2            WN     76.0      14.0       8.0       515    IND  BWI     407.0
# 3            WN     77.0      34.0      34.0       515    IND  BWI     401.0
# 4            WN     87.0      11.0      25.0       688    IND  JAX     474.0
#
#    ArrLate
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True

# %% [markdown]
# ### *Tabla las aerolineas con mas retrasos acumulados*

# %%
df2 = df.groupby("UniqueCarrier").ArrLate.sum("True") # agrupo las aerolineas y sumo los retrasos totales
df2 = df2.sort_values(ascending=False) # ordeno de manera descendente
df2.head(10) # muestro las 10 aerolineas con mas retrasos
# Out:
# UniqueCarrier
# WN    324717
# AA    172197
# MQ    130647
# UA    123989
# OO    121942
# DL    100923
# XE     94313
# CO     83646
# US     83262
# EV     75170
# Name: ArrLate, dtype: int64

# %% [markdown]
# # Ejercicio 3

# %% [markdown]
# ### *Exporta el data set limpio i las nuevas columnas a Excel*

# %%
df.to_excel("DelayedFlights2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d1b7d6d739ed> in <module>
# ----> 1 df.to_excel("DelayedFlights2.xlsx")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
#    2190             excel_writer,
#    2191             sheet_name=sheet_name,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     801         num_rows, num_cols = self.df.shape
#     802         if num_rows > self.max_rows or num_cols > self.max_cols:
# ...

# %%
# exporto en csv para evitar el error
df.to_csv("DelayedFlights2.csv")
